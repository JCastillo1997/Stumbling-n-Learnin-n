# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('amazon_database.csv')
df.head()
# Out:
#    uid        asin                                              title  stars  \
# 0    1  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 1    2  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...    4.7
# 2    3  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 3    4  B09B8T5VGV  Echo Dot with clock (5th generation, 2022 rele...    4.7
# 4    5  B09WX6QD65  Introducing Echo Pop | Full sound compact Wi-F...    4.6
#
#    reviews  price  isBestSeller  boughtInLastMonth        category
# 0    15308  21.99         False                  0  Hi-Fi Speakers
# 1    98099  23.99          True                  0  Hi-Fi Speakers
# 2    15308  21.99         False                  0  Hi-Fi Speakers
# 3     7205  31.99         False                  0  Hi-Fi Speakers
# 4     1881  17.99         False                  0  Hi-Fi Speakers

# %% [markdown]
# Frequency Tables:
#
# Generate a frequency table for the product category.
# Which are the top 5 most listed product categories?

# %%
df['category'].describe()
# Out:
# count               2443651
# unique                  296
# top       Sports & Outdoors
# freq                 836265
# Name: category, dtype: object

# %%
df['category'].isna().sum()
# Out:
# 0

# %%
df_v=df.category.value_counts().head()
df_v.head()
#Esto nos dice los cinco mas gustados
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
frecuency=df.category.value_counts().head()
frecuency.head()
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
sns.barplot(y=frecuency.index,x=frecuency.values)
plt.xticks(rotation=40)
plt.title('Best Sellers')
plt.ylabel('')
plt.xlabel('number of products')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
frecuency.plot.pie( startangle=90, autopct="%1.2f%%",explode=(0,0.2,0))
ylabel= ''
xlabel=''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 frecuency.plot.pie( startangle=90, autopct="%1.2f%%",explode=(0,0.2,0))
#       2 ylabel= ''
#       3 xlabel=''
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1589, in PlotAccessor.pie(self, **kwargs)
#    1583 if (
#    1584     isinstance(self._parent, ABCDataFrame)
#    1585     and kwargs.get("y", None) is None
#    1586     and not kwargs.get("subplots", False)
#    1587 ):
#    1588     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1589 return self(kind="pie", **kwargs)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1859, in PiePlot._make_plot(self)
#    1857 else:
#    1858     blabels = None
# -> 1859 results = ax.pie(y, labels=blabels, **kwds)
#    1861 if kwds.get("autopct", None) is not None:
#    1862     patches, texts, autotexts = results
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:3203, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3201     raise ValueError("'label' must be of length 'x'")
#    3202 if len(x) != len(explode):
# -> 3203     raise ValueError("'explode' must be of length 'x'")
#    3204 if colors is None:
#    3205     get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x'

# %%
frecuency.plot.pie(startangle=90, autopct="%1.2f%%", explode=(0,0.1,0.3,0.5,0.6))
# Out:
# <Axes: ylabel='count'>

# %%
np.percentile(df.price,25)
# Out:
# 9.99

# %% [markdown]
# Measures of Centrality:
#
# Calculate the mean, median, and mode for the price of products.
# What's the average price point of products listed? How does this compare with the most common price point (mode)?

# %%
df[['price']].describe().round().T
# Out:
#            count  mean    std  min   25%   50%   75%       max
# price  2443651.0  89.0  346.0  0.0  10.0  19.0  46.0  100000.0

# %%
# el salto cuantitativo entre la media y la moda indica mucha disparidad o algun valor o "outlier"

# %%
standard_deviation=df.price.max()-df.price.min()
#desvaicion estandar, un poco inutil viendo que lo que da probleams es que el valor minimo sea el 0
# Out:
# 100000.0

# %% [markdown]
# Measures of Dispersion:
#
# Determine the variance, standard deviation, range, and interquartile range for product price.
# How varied are the product prices? Are there any indicators of a significant spread in prices?
# Visualizations:
#
# Is there a specific price range where most products fall? Plot a histogram to visualize the distribution of product prices. If its hard to read these diagrams, think why this is, and explain how it could be solved..
# Are there products that are priced significantly higher than the rest? Use a box plot to showcase the spread and potential outliers in product pricing.

# %%
pd.qcut(df['price'],q=4).head(20)
# Out:
# 0        (19.09, 45.99]
# 1        (19.09, 45.99]
# 2        (19.09, 45.99]
# 3        (19.09, 45.99]
# 4         (9.99, 19.09]
# 5        (19.09, 45.99]
# 6        (19.09, 45.99]
# 7        (19.09, 45.99]
# 8        (19.09, 45.99]
# 9        (19.09, 45.99]
# 10    (45.99, 100000.0]
# 11        (9.99, 19.09]
# 12        (9.99, 19.09]
# 13    (45.99, 100000.0]
# 14    (45.99, 100000.0]
# 15       (19.09, 45.99]
# 16       (19.09, 45.99]
# 17       (19.09, 45.99]
# 18    (45.99, 100000.0]
# 19    (45.99, 100000.0]
# Name: price, dtype: category
# Categories (4, interval[float64, right]): [(-0.001, 9.99] < (9.99, 19.09] < (19.09, 45.99] < (45.99, 100000.0]]

# %%
bins = [0, 10, 30, 50, df['price'].max()]
labels = ['Low', 'Medium', 'High', 'Very High']

# %%
df['price_category'] = pd.cut(df['price'], bins=bins, labels=labels)

# %%
df.price_category
# Out:
# 0             Medium
# 1             Medium
# 2             Medium
# 3               High
# 4             Medium
#              ...
# 2443646       Medium
# 2443647    Very High
# 2443648    Very High
# 2443649    Very High
# 2443650    Very High
# Name: price_category, Length: 2443651, dtype: category
# Categories (4, object): ['Low' < 'Medium' < 'High' < 'Very High']

# %%
valores_2= df.price_category.value_counts()

# %%
sns.barplot(x= valores_2.index,y=valores_2.values)
# Out:
# <Axes: xlabel='price_category'>
